# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/home/wanakin/DATA/sammy_face.jpg')

# %%
plt.imshow(img)

# %%
edges = cv2.Canny(image=img,threshold1=lower+100,threshold2=upper+150)
plt.imshow(edges)

# %%
med_val = np.median(img)

# %%
med_val
# Out:
# 64.0

# %%
# LOWER THRESHOLD TO EITHER 0 OR 70% OF THE MEDIAN VALUE WICHEVER IS GREATER
lower = int(max(0,0.7*med_val))
# UPPER THRESHOLD TO EITHER 130% OF THE MEDIAN OR THE MAX 255, WICHEVER IS SMALLER
upper = int(min(255,1.3*med_val))

# %%
lower,upper
# Out:
# (44, 83)

# %%
blurred_img = cv2.blur(img,ksize=(5,5))
med_val = np.median(blurred_img)

# %%
edges = cv2.Canny(image=blurred_img,threshold1=lower,threshold2=upper+50)
plt.imshow(edges)
