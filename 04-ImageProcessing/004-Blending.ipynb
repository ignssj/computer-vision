# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread("/home/wanakin/DATA/dog_backpack.jpg")
img2 = cv2.imread("/home/wanakin/DATA/watermark_no_copy.png")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1 = cv2.resize(img1,(1200,1200))

# %%
img2 = cv2.resize(img2,(1200,1200))

# %%
blended = cv2.addWeighted(img1,0.9,img2,0.1,5)
plt.imshow(blended)

# %%
img2 = cv2.resize(img2,(200,200))
img2.shape
# Out:
# (200, 200, 3)

# %%
img1[500:700,500:700] = img2

# %%
plt.imshow(img1)
